# %% [markdown]
# <a href="https://colab.research.google.com/github/nelaaulina/UAS_G.231.20.0164/blob/main/UAS_KASUS_C_G231200164.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# upload gambar

from google.colab import files

file = files.upload()
# Out:
#      <input type="file" id="files-0ed893c5-a607-4539-a63b-0ec8b31079ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ed893c5-a607-4539-a63b-0ec8b31079ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# install libraries

# !pip install ultralytics -q
# !pip install pyyaml -q|
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 8.7 MB/s eta 0:00:00
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
# import libraries

from ultralytics import YOLO
import yaml
import cv2
from google.colab.patches import cv2_imshow

# %%
# instansiasi kelas YOLO

model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 45.1MB/s]

# %%
model.predict("anak anak.jpg", save = True, save_txt = True)
# Out:
# image 1/1 /content/anak anak.jpg: 384x640 11 persons, 1 teddy bear, 274.8ms
# Speed: 23.4ms preprocess, 274.8ms inference, 27.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
from IPython.display import Image
Image(filename="/content/runs/detect/predict/anak anak.jpg")
